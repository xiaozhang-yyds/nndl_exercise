# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
#test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
with torch.no_grad():
    test_x = torch.unsqueeze(test_data.data, dim=1).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels=1,      # MNIST 是灰度图像，输入通道为1
                out_channels=32,    # 输出32个特征图
                kernel_size=7,      # 7x7卷积核
                stride=1,           # 步长为1
                padding=3,          # 填充为3，使输出尺寸与输入相同 (7-1)/2=3
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels=32,     # 输入通道为32（与conv1的输出通道相同）
                out_channels=64,    # 输出64个特征图
                kernel_size=5,      # 5x5卷积核
                stride=1,           # 步长为1
                padding=2,          # 填充为2，使输出尺寸与输入相同 (5-1)/2=2
            ),
            nn.ReLU(),        # 激活函数
            nn.MaxPool2d(2),        # 2x2池化，将特征图尺寸再减半
            
         

        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), 7*7*64)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2, dim=1)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# ========== 20 ===== ===== test accuracy is  0.288 ==========
# ========== 40 ===== ===== test accuracy is  0.366 ==========
# ========== 60 ===== ===== test accuracy is  0.512 ==========
# ========== 80 ===== ===== test accuracy is  0.558 ==========
# ========== 100 ===== ===== test accuracy is  0.62 ==========
# ========== 120 ===== ===== test accuracy is  0.704 ==========
# ========== 140 ===== ===== test accuracy is  0.73 ==========
# ========== 160 ===== ===== test accuracy is  0.76 ==========
# ========== 180 ===== ===== test accuracy is  0.786 ==========
# ========== 200 ===== ===== test accuracy is  0.802 ==========
# ========== 220 ===== ===== test accuracy is  0.83 ==========
# ========== 240 ===== ===== test accuracy is  0.852 ==========
# ========== 260 ===== ===== test accuracy is  0.854 ==========
# ========== 280 ===== ===== test accuracy is  0.846 ==========
# ========== 300 ===== ===== test accuracy is  0.872 ==========
# ========== 320 ===== ===== test accuracy is  0.846 ==========
# ========== 340 ===== ===== test accuracy is  0.864 ==========
# ========== 360 ===== ===== test accuracy is  0.872 ==========
# ========== 380 ===== ===== test accuracy is  0.892 ==========
# ========== 400 ===== ===== test accuracy is  0.898 ==========
# ========== 420 ===== ===== test accuracy is  0.874 ==========
# ========== 440 ===== ===== test accuracy is  0.88 ==========
# ========== 460 ===== ===== test accuracy is  0.914 ==========
# ========== 480 ===== ===== test accuracy is  0.902 ==========
# ========== 500 ===== ===== test accuracy is  0.91 ==========
# ========== 520 ===== ===== test accuracy is  0.914 ==========
# ========== 540 ===== ===== test accuracy is  0.916 ==========
# ========== 560 ===== ===== test accuracy is  0.926 ==========
# ========== 580 ===== ===== test accuracy is  0.918 ==========
# ========== 600 ===== ===== test accuracy is  0.934 ==========
# ========== 620 ===== ===== test accuracy is  0.924 ==========
# ========== 640 ===== ===== test accuracy is  0.932 ==========
# ========== 660 ===== ===== test accuracy is  0.916 ==========
# ========== 680 ===== ===== test accuracy is  0.926 ==========
# ========== 700 ===== ===== test accuracy is  0.916 ==========
# ========== 720 ===== ===== test accuracy is  0.926 ==========
# ========== 740 ===== ===== test accuracy is  0.928 ==========
# ========== 760 ===== ===== test accuracy is  0.938 ==========
# ========== 780 ===== ===== test accuracy is  0.926 ==========
# ========== 800 ===== ===== test accuracy is  0.944 ==========
# ========== 820 ===== ===== test accuracy is  0.918 ==========
# ========== 840 ===== ===== test accuracy is  0.94 ==========
# ========== 860 ===== ===== test accuracy is  0.934 ==========
# ========== 880 ===== ===== test accuracy is  0.946 ==========
# ========== 900 ===== ===== test accuracy is  0.94 ==========
# ========== 920 ===== ===== test accuracy is  0.938 ==========
# ========== 940 ===== ===== test accuracy is  0.948 ==========
# ========== 960 ===== ===== test accuracy is  0.94 ==========
# ========== 980 ===== ===== test accuracy is  0.948 ==========
# ========== 1000 ===== ===== test accuracy is  0.93 ==========
# ========== 1020 ===== ===== test accuracy is  0.932 ==========
# ========== 1040 ===== ===== test accuracy is  0.954 ==========
# ========== 1060 ===== ===== test accuracy is  0.95 ==========
# ========== 1080 ===== ===== test accuracy is  0.948 ==========
# ========== 1100 ===== ===== test accuracy is  0.95 ==========
# ========== 1120 ===== ===== test accuracy is  0.962 ==========
# ========== 1140 ===== ===== test accuracy is  0.946 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.95 ==========
# ========== 20 ===== ===== test accuracy is  0.95 ==========
# ========== 40 ===== ===== test accuracy is  0.948 ==========
# ========== 60 ===== ===== test accuracy is  0.958 ==========
# ========== 80 ===== ===== test accuracy is  0.954 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.95 ==========
# ========== 140 ===== ===== test accuracy is  0.96 ==========
# ========== 160 ===== ===== test accuracy is  0.958 ==========
# ========== 180 ===== ===== test accuracy is  0.966 ==========
# ========== 200 ===== ===== test accuracy is  0.954 ==========
# ========== 220 ===== ===== test accuracy is  0.958 ==========
# ========== 240 ===== ===== test accuracy is  0.962 ==========
# ========== 260 ===== ===== test accuracy is  0.956 ==========
# ========== 280 ===== ===== test accuracy is  0.97 ==========
# ========== 300 ===== ===== test accuracy is  0.954 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.968 ==========
# ========== 360 ===== ===== test accuracy is  0.956 ==========
# ========== 380 ===== ===== test accuracy is  0.962 ==========
# ========== 400 ===== ===== test accuracy is  0.956 ==========
# ========== 420 ===== ===== test accuracy is  0.962 ==========
# ========== 440 ===== ===== test accuracy is  0.964 ==========
# ========== 460 ===== ===== test accuracy is  0.964 ==========
# ========== 480 ===== ===== test accuracy is  0.964 ==========
# ========== 500 ===== ===== test accuracy is  0.96 ==========
# ========== 520 ===== ===== test accuracy is  0.962 ==========
# ========== 540 ===== ===== test accuracy is  0.962 ==========
# ========== 560 ===== ===== test accuracy is  0.966 ==========
# ========== 580 ===== ===== test accuracy is  0.968 ==========
# ========== 600 ===== ===== test accuracy is  0.964 ==========
# ========== 620 ===== ===== test accuracy is  0.968 ==========
# ========== 640 ===== ===== test accuracy is  0.96 ==========
# ========== 660 ===== ===== test accuracy is  0.974 ==========
# ========== 680 ===== ===== test accuracy is  0.96 ==========
# ========== 700 ===== ===== test accuracy is  0.968 ==========
# ========== 720 ===== ===== test accuracy is  0.958 ==========
# ========== 740 ===== ===== test accuracy is  0.964 ==========
# ========== 760 ===== ===== test accuracy is  0.97 ==========
# ========== 780 ===== ===== test accuracy is  0.96 ==========
# ========== 800 ===== ===== test accuracy is  0.96 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.968 ==========
# ========== 860 ===== ===== test accuracy is  0.962 ==========
# ========== 880 ===== ===== test accuracy is  0.966 ==========
# ========== 900 ===== ===== test accuracy is  0.978 ==========
# ========== 920 ===== ===== test accuracy is  0.964 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.96 ==========
# ========== 980 ===== ===== test accuracy is  0.964 ==========
# ========== 1000 ===== ===== test accuracy is  0.958 ==========
# ========== 1020 ===== ===== test accuracy is  0.96 ==========
# ========== 1040 ===== ===== test accuracy is  0.962 ==========
# ========== 1060 ===== ===== test accuracy is  0.96 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.968 ==========
# ========== 1120 ===== ===== test accuracy is  0.96 ==========
# ========== 1140 ===== ===== test accuracy is  0.962 ==========
# ========== 1160 ===== ===== test accuracy is  0.964 ==========
# ========== 1180 ===== ===== test accuracy is  0.964 ==========
# ========== 20 ===== ===== test accuracy is  0.972 ==========
# ========== 40 ===== ===== test accuracy is  0.974 ==========
# ========== 60 ===== ===== test accuracy is  0.972 ==========
# ========== 80 ===== ===== test accuracy is  0.97 ==========
# ========== 100 ===== ===== test accuracy is  0.966 ==========
# ========== 120 ===== ===== test accuracy is  0.972 ==========
# ========== 140 ===== ===== test accuracy is  0.974 ==========
# ========== 160 ===== ===== test accuracy is  0.966 ==========
# ========== 180 ===== ===== test accuracy is  0.976 ==========
# ========== 200 ===== ===== test accuracy is  0.958 ==========
# ========== 220 ===== ===== test accuracy is  0.974 ==========
# ========== 240 ===== ===== test accuracy is  0.97 ==========
# ========== 260 ===== ===== test accuracy is  0.974 ==========
# ========== 280 ===== ===== test accuracy is  0.972 ==========
# ========== 300 ===== ===== test accuracy is  0.974 ==========
# ========== 320 ===== ===== test accuracy is  0.968 ==========
# ========== 340 ===== ===== test accuracy is  0.978 ==========
# ========== 360 ===== ===== test accuracy is  0.968 ==========
# ========== 380 ===== ===== test accuracy is  0.98 ==========
# ========== 400 ===== ===== test accuracy is  0.974 ==========
# ========== 420 ===== ===== test accuracy is  0.972 ==========
# ========== 440 ===== ===== test accuracy is  0.974 ==========
# ========== 460 ===== ===== test accuracy is  0.976 ==========
# ========== 480 ===== ===== test accuracy is  0.972 ==========
# ========== 500 ===== ===== test accuracy is  0.974 ==========
# ========== 520 ===== ===== test accuracy is  0.976 ==========
# ========== 540 ===== ===== test accuracy is  0.974 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.978 ==========
# ========== 600 ===== ===== test accuracy is  0.972 ==========
# ========== 620 ===== ===== test accuracy is  0.974 ==========
# ========== 640 ===== ===== test accuracy is  0.978 ==========
# ========== 660 ===== ===== test accuracy is  0.984 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.978 ==========
# ========== 720 ===== ===== test accuracy is  0.978 ==========
# ========== 740 ===== ===== test accuracy is  0.97 ==========
# ========== 760 ===== ===== test accuracy is  0.976 ==========
# ========== 780 ===== ===== test accuracy is  0.98 ==========
# ========== 800 ===== ===== test accuracy is  0.982 ==========
# ========== 820 ===== ===== test accuracy is  0.974 ==========
# ========== 840 ===== ===== test accuracy is  0.978 ==========
# ========== 860 ===== ===== test accuracy is  0.976 ==========
# ========== 880 ===== ===== test accuracy is  0.968 ==========
# ========== 900 ===== ===== test accuracy is  0.982 ==========
# ========== 920 ===== ===== test accuracy is  0.964 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.972 ==========
# ========== 980 ===== ===== test accuracy is  0.974 ==========
# ========== 1000 ===== ===== test accuracy is  0.972 ==========
# ========== 1020 ===== ===== test accuracy is  0.97 ==========
# ========== 1040 ===== ===== test accuracy is  0.978 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.97 ==========
# ========== 1100 ===== ===== test accuracy is  0.976 ==========
# ========== 1120 ===== ===== test accuracy is  0.976 ==========
# ========== 1140 ===== ===== test accuracy is  0.974 ==========
# ========== 1160 ===== ===== test accuracy is  0.984 ==========
# ========== 1180 ===== ===== test accuracy is  0.978 ==========
